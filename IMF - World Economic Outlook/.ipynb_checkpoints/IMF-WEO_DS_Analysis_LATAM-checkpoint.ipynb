# %% [markdown]
# # IMF - World Economic Outlook database
# Notebook developed by Marcelo Rovai - UDD-MDS - July 2018

# %% [markdown]
# ### Definitions:
# All definitions can be found on file:
# - WEOApr2018_SDMXDSD.XLSX
# - For example: 'LUR' : Unemployment rate as Percent of total labor force.
# ### Dataset:
# http://www.imf.org/external/pubs/ft/weo/2018/01/weodata/download.aspx
# - The original dataset is separated by tabs (WEOApr2018all.xls)
# - Excel was used to read it and save it as .csv (World_Economic_Outlook_Database_Apr18.csv)
# - Estimates started on 2016

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ls
# Out:
#  El volumen de la unidad C es Windows
#  El número de serie del volumen es: 64D2-4BAF
#
#  Directorio de C:\Users\AX201 GMRS\Dropbox\REPOS\Python4DS\IMF - World Economic Outlook
#
# 25/04/2020  03:08 p.m.    <DIR>          .
# 25/04/2020  03:08 p.m.    <DIR>          ..
# 25/04/2020  03:08 p.m.    <DIR>          .ipynb_checkpoints
# 25/04/2020  03:08 p.m.           100,643 IMF-WEO_DS_Analysis_LATAM.ipynb
# 25/04/2020  03:08 p.m.            32,430 latam_unemployment.png
# 25/04/2020  01:31 p.m.            61,867 WEOApr2018_SDMXDSD.XLSX
# 25/04/2020  01:31 p.m.         9,172,221 WEOApr2018all.xls
# 25/04/2020  01:31 p.m.         9,208,389 World_Economic_Outlook_Database_Apr18.csv
#                5 archivos     18,575,550 bytes
#                3 dirs  746,282,127,360 bytes libres

# %%
# Load dataset
df = pd.read_csv('World_Economic_Outlook_Database_Apr18.csv')
df.shape # (8687, 54)
# Out:
# (8687, 54)

# %%
df.head()
# Out:
#   WEO Country Code  ISO WEO Subject Code      Country  \
# 0              512  AFG           NGDP_R  Afghanistan
# 1              512  AFG        NGDP_RPCH  Afghanistan
# 2              512  AFG             NGDP  Afghanistan
# 3              512  AFG            NGDPD  Afghanistan
# 4              512  AFG           PPPGDP  Afghanistan
#
#                         Subject Descriptor  \
# 0  Gross domestic product, constant prices
# 1  Gross domestic product, constant prices
# 2   Gross domestic product, current prices
# 3   Gross domestic product, current prices
# 4   Gross domestic product, current prices
#
#                                        Subject Notes  \
# 0  Expressed in billions of national currency uni...
# 1  Annual percentages of constant price GDP are y...
# 2  Expressed in billions of national currency uni...
# 3  Values are based upon GDP in national currency...
# 4  These data form the basis for the country weig...
#
#                                             Units     Scale  \
# 0                               National currency  Billions
# 1                                  Percent change       NaN
# 2                               National currency  Billions
# 3                                    U.S. dollars  Billions
# 4  Purchasing power parity; international dollars  Billions
#
#                        Country/Series-specific Notes 1980  ...      2015  \
# 0  Source: National Statistics Office Latest actu...  NaN  ...    484.17
# 1  See notes for:  Gross domestic product, consta...  NaN  ...      1.31
# 2  Source: National Statistics Office Latest actu...  NaN  ...  1,227.95
# 3  See notes for:  Gross domestic product, curren...  NaN  ...    20.079
# 4  See notes for:  Gross domestic product, curren...  NaN  ...    64.292
#
#        2016      2017      2018      2019      2020      2021      2022  \
# 0   495.629   508.044   520.745   536.276   554.949   577.058   602.932
# 1     2.367     2.505       2.5     2.982     3.482     3.984     4.484
# 2  1,320.24  1,422.01  1,531.95  1,656.57  1,799.95  1,965.32  2,156.19
# 3    19.454    20.889    21.657    22.925    24.244     25.86    27.783
# 4    66.654    69.553    72.911    76.714    80.945    85.774    91.159
#
#        2023 Estimates Start After
# 0   632.983                2016.0
# 1     4.984                2016.0
# 2  2,376.89                2016.0
# 3        30                2016.0
# 4    97.367                2016.0
#
# [5 rows x 54 columns]

# %%
# df.info() # Note that data on each year is a 'string' (dtype: object). Must be converted to float

# %% [markdown]
# ### Selecting Countries to be part of dataset

# %%
df_latam = df[(df.Country == 'Argentina') | 
              (df.Country == 'Brazil') | 
              (df.Country == 'Chile') | 
              (df.Country == 'Peru') |
              (df.Country == 'Venezuela') |
              (df.Country == 'Mexico')]

# %%
df_latam.tail()
# Out:
#      WEO Country Code  ISO WEO Subject Code    Country  \
# 8500              299  VEN           GGXWDG  Venezuela
# 8501              299  VEN      GGXWDG_NGDP  Venezuela
# 8502              299  VEN          NGDP_FY  Venezuela
# 8503              299  VEN              BCA  Venezuela
# 8504              299  VEN        BCA_NGDPD  Venezuela
#
#                                      Subject Descriptor  \
# 8500                      General government gross debt
# 8501                      General government gross debt
# 8502  Gross domestic product corresponding to fiscal...
# 8503                            Current account balance
# 8504                            Current account balance
#
#                                           Subject Notes              Units  \
# 8500  Gross debt consists of all liabilities that re...  National currency
# 8501  Gross debt consists of all liabilities that re...     Percent of GDP
# 8502  Gross domestic product corresponding to fiscal...  National currency
# 8503  Current account is all transactions other than...       U.S. dollars
# 8504  Current account is all transactions other than...     Percent of GDP
#
#          Scale                      Country/Series-specific Notes   1980  ...  \
# 8500  Billions  Source: Ministry of Finance or Treasury Latest...    NaN  ...
# 8501       NaN  See notes for:  General government gross debt ...    NaN  ...
# 8502  Billions  Source: Ministry of Finance or Treasury Latest...    0.3  ...
# 8503  Billions  Source: Central Bank. http://www.bcv.org.ve/c2...  5.176  ...
# 8504       NaN  See notes for:  Gross domestic product, curren...  7.411  ...
#
#           2015       2016        2017           2018              2019  \
# 8500  2,544.18   8,896.59  102,300.39  56,954,757.81  7,098,743,795.91
# 8501    31.927     31.299      34.866        161.986           172.077
# 8502  7,968.66  28,424.75  293,408.72  35,160,202.90  4,125,335,707.11
# 8503   -16.051      -3.87       4.277          2.421             3.336
# 8504    -6.616     -1.639       2.036            2.4              3.61
#
#                     2020                   2021                    2022  \
# 8500  881,224,435,190.00    110,696,096,674,818  13,826,953,867,451,900
# 8501             168.141                165.485                 160.409
# 8502  524,097,427,161.95  66,891,727,514,064.60   8,619,791,134,782,530
# 8503                0.54                  2.198                   2.067
# 8504               0.633                  2.682                   2.644
#
#                            2023 Estimates Start After
# 8500  1,756,278,772,130,830,000                2013.0
# 8501                    157.681                2013.0
# 8502  1,113,817,843,651,120,000                2013.0
# 8503                      1.866                2016.0
# 8504                      2.523                2016.0
#
# [5 rows x 54 columns]

# %%
# Filter 'LUR' : Unemployment rate for selected countries:
df_latam_un = df_latam[df_latam['WEO Subject Code'] == 'LUR']

# %%
df_latam_un
# Out:
#      WEO Country Code  ISO WEO Subject Code    Country Subject Descriptor  \
# 250               213  ARG              LUR  Argentina  Unemployment rate
# 1015              223  BRA              LUR     Brazil  Unemployment rate
# 1510              228  CHL              LUR      Chile  Unemployment rate
# 4975              273  MEX              LUR     Mexico  Unemployment rate
# 6010              293  PER              LUR       Peru  Unemployment rate
# 8485              299  VEN              LUR  Venezuela  Unemployment rate
#
#                                           Subject Notes  \
# 250   Unemployment rate can be defined by either the...
# 1015  Unemployment rate can be defined by either the...
# 1510  Unemployment rate can be defined by either the...
# 4975  Unemployment rate can be defined by either the...
# 6010  Unemployment rate can be defined by either the...
# 8485  Unemployment rate can be defined by either the...
#
#                              Units Scale  \
# 250   Percent of total labor force   NaN
# 1015  Percent of total labor force   NaN
# 1510  Percent of total labor force   NaN
# 4975  Percent of total labor force   NaN
# 6010  Percent of total labor force   NaN
# 8485  Percent of total labor force   NaN
#
#                           Country/Series-specific Notes    1980  ...   2015  \
# 250   Source: National Statistics Office Latest actu...       3  ...    NaN
# 1015  Source: National Statistics Office Latest actu...     NaN  ...    8.3
# 1510  Source: National Statistics Office Latest actu...  11.502  ...  6.214
# 4975  Source: National Statistics Office Latest actu...     1.2  ...   4.35
# 6010  Source: National Statistics Office Latest actu...   7.326  ...   6.44
# 8485  Source: National Statistics Office Latest actu...     NaN  ...    7.4
#
#         2016    2017   2018    2019    2020    2021    2022    2023  \
# 250    8.467    8.35   8.04   7.469   6.967   6.539   6.075       6
# 1015  11.267  12.767   11.6    10.5    10.1     9.8     9.5     9.5
# 1510    6.49   6.674  6.238     5.8   5.863     5.9   5.975       6
# 4975   3.882    3.42    3.5   3.446    3.42   3.411   3.405   3.426
# 6010    6.71    6.71   6.71    6.71    6.71    6.71    6.71    6.71
# 8485  20.638  27.096  33.35  37.399  39.179  40.774  42.327  44.315
#
#      Estimates Start After
# 250                 2016.0
# 1015                2017.0
# 1510                2017.0
# 4975                2016.0
# 6010                2017.0
# 8485                2011.0
#
# [6 rows x 54 columns]

# %%
# delete columns
del df_latam_un['ISO']
del df_latam_un['WEO Country Code']
del df_latam_un['WEO Subject Code']
del df_latam_un['Subject Descriptor']
del df_latam_un['Subject Notes']
del df_latam_un['Units']
del df_latam_un['Scale']
del df_latam_un['Country/Series-specific Notes']
del df_latam_un['Estimates Start After']

# %%
df_latam_un
# Out:
#         Country    1980    1981    1982    1983    1984    1985    1986  \
# 250   Argentina       3       5     4.5       5       5    6.25     6.3
# 1015     Brazil     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1510      Chile  11.502  10.291  19.814  20.999  17.515  14.975  12.299
# 4975     Mexico     1.2     0.9     4.2     6.1     5.6     4.4     4.3
# 6010       Peru   7.326     6.8     6.4       9     8.9   4.589     5.3
# 8485  Venezuela     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#         1987   1988  ...   2014   2015    2016    2017   2018    2019    2020  \
# 250        6    6.5  ...   7.25    NaN   8.467    8.35   8.04   7.469   6.967
# 1015     NaN    NaN  ...  6.792    8.3  11.267  12.767   11.6    10.5    10.1
# 1510  10.984  9.875  ...  6.392  6.214    6.49   6.674  6.238     5.8   5.863
# 4975   3.883  3.542  ...  4.823   4.35   3.882    3.42    3.5   3.446    3.42
# 6010     4.8  4.156  ...   6.03   6.44    6.71    6.71   6.71    6.71    6.71
# 8485     NaN    NaN  ...    6.7    7.4  20.638  27.096  33.35  37.399  39.179
#
#         2021    2022    2023
# 250    6.539   6.075       6
# 1015     9.8     9.5     9.5
# 1510     5.9   5.975       6
# 4975   3.411   3.405   3.426
# 6010    6.71    6.71    6.71
# 8485  40.774  42.327  44.315
#
# [6 rows x 45 columns]

# %%
# use of "Country" as index
# drop=True which will remove the column, and inplace=True instead of having to 
# assign the variable back to itself or to a new variable name.

df_latam_un.set_index('Country',drop=True,inplace=True)

# %%
df_latam_un
# Out:
#              1980    1981    1982    1983    1984    1985    1986    1987  \
# Country
# Argentina       3       5     4.5       5       5    6.25     6.3       6
# Brazil        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Chile      11.502  10.291  19.814  20.999  17.515  14.975  12.299  10.984
# Mexico        1.2     0.9     4.2     6.1     5.6     4.4     4.3   3.883
# Peru        7.326     6.8     6.4       9     8.9   4.589     5.3     4.8
# Venezuela     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#             1988   1989  ...   2014   2015    2016    2017   2018    2019  \
# Country                  ...
# Argentina    6.5      8  ...   7.25    NaN   8.467    8.35   8.04   7.469
# Brazil       NaN    NaN  ...  6.792    8.3  11.267  12.767   11.6    10.5
# Chile      9.875   7.98  ...  6.392  6.214    6.49   6.674  6.238     5.8
# Mexico     3.542  2.925  ...  4.823   4.35   3.882    3.42    3.5   3.446
# Peru       4.156    7.9  ...   6.03   6.44    6.71    6.71   6.71    6.71
# Venezuela    NaN    NaN  ...    6.7    7.4  20.638  27.096  33.35  37.399
#
#              2020    2021    2022    2023
# Country
# Argentina   6.967   6.539   6.075       6
# Brazil       10.1     9.8     9.5     9.5
# Chile       5.863     5.9   5.975       6
# Mexico       3.42   3.411   3.405   3.426
# Peru         6.71    6.71    6.71    6.71
# Venezuela  39.179  40.774  42.327  44.315
#
# [6 rows x 44 columns]

# %%
# Let's consider years as lines:
df_latam_un = df_latam_un.transpose()

# %%
df_latam_un.head()
# Out:
# Country Argentina Brazil   Chile Mexico   Peru Venezuela
# 1980            3    NaN  11.502    1.2  7.326       NaN
# 1981            5    NaN  10.291    0.9    6.8       NaN
# 1982          4.5    NaN  19.814    4.2    6.4       NaN
# 1983            5    NaN  20.999    6.1      9       NaN
# 1984            5    NaN  17.515    5.6    8.9       NaN

# %%
# df_latam_un.rename(columns={'Country': 'Year'})

# %%
# Verify what is the type of data
df_latam_un['Argentina'].head()
# Out:
# 1980      3
# 1981      5
# 1982    4.5
# 1983      5
# 1984      5
# Name: Argentina, dtype: object

# %%
# The data for each year is a 'string' (dtype: object). Must be converted to float
df_latam_un = df_latam_un.astype('float64')

# %%
# Check if data is now a float.
df_latam_un['Argentina'].head()
# Out:
# 1980    3.0
# 1981    5.0
# 1982    4.5
# 1983    5.0
# 1984    5.0
# Name: Argentina, dtype: float64

# %% [markdown]
# ### Visualization

# %%
import seaborn as sns
sns.set()

# %%
plt.figure(figsize=(20,10))
plt.grid(True)

plt.xlabel('Year')
plt.ylabel('rate as Percent of total labor force')
plt.title('LATAM Unemployment rate')

plt.plot(df_latam_un.Argentina)
plt.plot(df_latam_un.Chile, linewidth=4)
plt.plot(df_latam_un.Brazil)
plt.plot(df_latam_un.Mexico)
plt.plot(df_latam_un.Peru)
plt.plot(df_latam_un.Venezuela)

plt.legend()

x1, y1 = [2016, 2016], [0, 50]
plt.plot(x1, y1, marker = 'o', color='r')
plt.text(x=2017, y= 48, s='ESTIMATED DATA FROM 2016')
plt.text(x=2017, y= 53, s='UDD-MDS Macroeconomia - July08')
plt.text(x=1995, y= -8, s='Data from IMF - "World Economic Outlook database"')
plt.savefig('latam_unemployment')
# Out:
# No handles with labels found to put in legend.
